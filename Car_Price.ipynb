# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt      
import seaborn as sns 

data_df = pd.read_csv("./car_price_prediction_.csv")
data_df.head()
# Out:
#    Car ID  Brand  Year  Engine Size Fuel Type Transmission  Mileage Condition  \
# 0       1  Tesla  2016          2.3    Petrol       Manual   114832       New
# 1       2    BMW  2018          4.4  Electric       Manual   143190      Used
# 2       3   Audi  2013          4.5  Electric       Manual   181601       New
# 3       4  Tesla  2011          4.1    Diesel    Automatic    68682       New
# 4       5   Ford  2009          2.6    Diesel       Manual   223009  Like New
#
#       Price     Model
# 0  26613.92   Model X
# 1  14679.61  5 Series
# 2  44402.61        A4
# 3  86374.33   Model Y
# 4  73577.10   Mustang

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt      
import seaborn as sns 

data_df = pd.read_csv("./car_price_prediction_.csv")
data_df.head().style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style type="text/css">
# #T_aa23a_row0_col0, #T_aa23a_row0_col3, #T_aa23a_row1_col8, #T_aa23a_row3_col6, #T_aa23a_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_aa23a_row0_col2 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_aa23a_row0_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_aa23a_row0_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_aa23a_row1_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_aa23a_row1_col2, #T_aa23a_row2_col3, #T_aa23a_row3_col8, #T_aa23a_row4_col0, #T_aa23a_row4_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_aa23a_row1_col3 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_aa23a_row1_col6 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_aa23a_row2_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_aa23a_row2_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_aa23a_row2_col6 {
# ...
